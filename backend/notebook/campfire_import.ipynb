# %%
import os
from dotenv import load_dotenv
from neo4j import GraphDatabase
from neo4j import Driver
from neo4j import Record
from neo4j.graph import Node


load_dotenv("../../.env")
# Out:
# True

# %%
user = os.environ["neo4j_user"]
pswd = os.environ["neo4j_pswd"]
driver: Driver = GraphDatabase.driver(
    uri="bolt://neo4j", auth=(user, pswd), database="neo4j"
)

# %%
def _select(tx, query: str, **props):
    results = tx.run(query, **props)
    return list(results)

# %%
def select_query(query: str, **props):
    results = []
    with driver.session() as session:
        results = session.execute_read(_select, query, **props)
    return results

# %%
query = """
match (pr:ProjectRoot)--(dr:ProjectDataRoot) 
with pr, count(dr.execution_id) as cnt
where cnt >= 10
match (pr)-[*]->(pj:Project)-->(pd:ProjectDetails)
return cnt, pr, pj, pd
order by cnt desc, pj.project_id, pj.sortby
"""

# %%
results: list[Record] = select_query(query)

# %%
len(results)
# Out:
# 4400

# %%
import datetime

# %%
def nvl(val, default):
    return val if val is not None else default

# %%
records = []

for rec in results:
    # return の順番で取得 ('*' の場合は、アルファベット順)
    n_dates, pr, pj, pd = rec.values()
    created_at = datetime.datetime.strptime(pj["created_at"], "%Y-%m-%d")
    record = dict(
        execution_id=pj["execution_id"],
        project_id=pj["project_id"],
        project_url=pj["project_url"],
        title=pj["title"],
        data_brand=pj["data_brand"],
        data_category=pj["data_category"],
        data_dimension=pj["data_dimension"],
        sortby=pj["sortby"],
        data_position=int(pj["data_position"]),
        current_funding=int(nvl(pj["current_funding"], 0)),
        current_supporters=int(nvl(pj["current_supporters"], 0)),
        success_rate=int(nvl(pj["success_rate"], 0)),  # %
        remaining_days=int(nvl(pj["remaining_days"], -1)),
        created_at=created_at,
    )
    records.append(record)

# %%
len(records)
# Out:
# 4400

# %%
dict(pj.items())
# Out:
# {'data_list': 'projects_popular_page4',
#  'project_type': 'ビューティー・ヘルスケア',
#  'fetch_id': 'FCH01HTAN9C1N09YE7S0NV58HKPH1',
#  'prefecture': '愛知県',
#  'created_at': '2024-04-01',
#  'data_category': 'category_beauty',
#  'project_url': 'https://camp-fire.jp/projects/view/745680',
#  'data_brand': 'sp_gadget',
#  'title': '新時代到来！寝ながら本格マッサージ！下からほぐす仰向けマッサージベッド 雅夢寝',
#  'current_funding': 837600,
#  'execution_id': '20240401010001',
#  'project_data_id': 'PRJ01HTANBBGR2RZ87J1Q795JQ03D',
#  'data_position': '6',
#  'user_id': 'Primedirect_21',
#  'img_url': 'https://static.camp-fire.jp/uploads/project_version/image/1170347/aabe2dfc-b448-4855-841a-55921bf78702.jpeg?ixlib=rails-2.1.4&fit=max&auto=format&w=600',
#  'project_id': '745680',
#  'current_supporters': 12,
#  'data_dimension': 'project',
#  'sortby': 'popular',
#  'source_id': 'Campfire',
#  'success_rate': 837,
#  'remaining_days': 7,
#  'status': 'OPEN'}

# %%
import pandas as pd

df = pd.DataFrame(records)
df.head()
# Out:
#      execution_id project_id                                project_url  \
# 0  20240319003003     735372  https://camp-fire.jp/projects/view/735372
# 1  20240320010001     735372  https://camp-fire.jp/projects/view/735372
# 2  20240321010001     735372  https://camp-fire.jp/projects/view/735372
# 3  20240322010002     735372  https://camp-fire.jp/projects/view/735372
# 4  20240324010002     735372  https://camp-fire.jp/projects/view/735372
#
#                              title        data_brand     data_category  \
# 0  元特殊部隊員が考案したタクティカルライト『CRISIS 01』  customer_success  category_product
# 1  元特殊部隊員が考案したタクティカルライト『CRISIS 01』  customer_success  category_product
# 2  元特殊部隊員が考案したタクティカルライト『CRISIS 01』  customer_success  category_product
# 3  元特殊部隊員が考案したタクティカルライト『CRISIS 01』  customer_success  category_product
# 4  元特殊部隊員が考案したタクティカルライト『CRISIS 01』  customer_success  category_product
#
#   data_dimension       sortby  data_position  current_funding  \
# 0        project  most_funded             14         61053067
# 1        project  most_funded             14         61366887
# 2        project  most_funded             14         61519507
# 3        project  most_funded             14         61627007
# 4        project  most_funded              9         65584727
#
#    current_supporters  success_rate  remaining_days created_at
# 0                1521          1221              12 2024-03-19
# 1                1530          1227              11 2024-03-20
# 2                1534          1230              10 2024-03-21
# 3                1536          1232               9 2024-03-22
# 4                2093          1311               7 2024-03-24

# %%
"project_data_id" in df.columns
# Out:
# False

# %%
# set index
keys = ["project_id", "execution_id", "sortby"]
df.index = [df[k] for k in keys]
df.drop(columns=keys, inplace=True)
df.head()
# Out:
#                                                                      project_url  \
# project_id execution_id   sortby
# 735372     20240319003003 most_funded  https://camp-fire.jp/projects/view/735372
#            20240320010001 most_funded  https://camp-fire.jp/projects/view/735372
#            20240321010001 most_funded  https://camp-fire.jp/projects/view/735372
#            20240322010002 most_funded  https://camp-fire.jp/projects/view/735372
#            20240324010002 most_funded  https://camp-fire.jp/projects/view/735372
#
#                                                                  title  \
# project_id execution_id   sortby
# 735372     20240319003003 most_funded  元特殊部隊員が考案したタクティカルライト『CRISIS 01』
#            20240320010001 most_funded  元特殊部隊員が考案したタクティカルライト『CRISIS 01』
#            20240321010001 most_funded  元特殊部隊員が考案したタクティカルライト『CRISIS 01』
#            20240322010002 most_funded  元特殊部隊員が考案したタクティカルライト『CRISIS 01』
#            20240324010002 most_funded  元特殊部隊員が考案したタクティカルライト『CRISIS 01』
#
#                                              data_brand     data_category  \
# project_id execution_id   sortby
# 735372     20240319003003 most_funded  customer_success  category_product
#            20240320010001 most_funded  customer_success  category_product
#            20240321010001 most_funded  customer_success  category_product
#            20240322010002 most_funded  customer_success  category_product
#            20240324010002 most_funded  customer_success  category_product
#
#                                       data_dimension  data_position  \
# project_id execution_id   sortby
# 735372     20240319003003 most_funded        project             14
#            20240320010001 most_funded        project             14
#            20240321010001 most_funded        project             14
#            20240322010002 most_funded        project             14
#            20240324010002 most_funded        project              9
#
#                                        current_funding  current_supporters  \
# project_id execution_id   sortby
# 735372     20240319003003 most_funded         61053067                1521
#            20240320010001 most_funded         61366887                1530
#            20240321010001 most_funded         61519507                1534
#            20240322010002 most_funded         61627007                1536
#            20240324010002 most_funded         65584727                2093
#
#                                        success_rate  remaining_days created_at
# project_id execution_id   sortby
# 735372     20240319003003 most_funded          1221              12 2024-03-19
#            20240320010001 most_funded          1227              11 2024-03-20
#            20240321010001 most_funded          1230              10 2024-03-21
#            20240322010002 most_funded          1232               9 2024-03-22
#            20240324010002 most_funded          1311               7 2024-03-24

# %%
from sqlalchemy import create_engine, Engine

engine: Engine = create_engine(
    "postgresql://postgres:postgres@postgresql:5432/campfire_db"
)
df.to_sql(
    "projects",
    engine,
    if_exists="replace",
    index=True,
    index_label=keys,
)
# Out:
# 400

# %% [markdown]
# # Design Note
#
# - data at pj.remaining_days -> pj.success_rate, pj.current_funding, pj.current_supporters
#     - data: pj.data_position, pj.project_type, pj.data_category, pj.data_brand, pj.prefecture, pj.sortby, pd.title, pd.article_text, pd.type, pd.profile_text, pd.project_experience
# - cypher では、明示的に GROUP BY でグルーピングできないので、pandas に変換してから グループ化してグループ単位で処理をする

# %%
from collections import namedtuple


def to_nt(dict_obj, typename="MyNamedTuple", defaults: dict = {}):
    dct = dict(dict_obj.items())
    # 辞書のキーをフィールド名として、名前付きタプルの型を定義
    for k, v in defaults.items():
        dct[k] = v
    NT = namedtuple(typename, dct.keys())
    # 名前付きタプルのインスタンスを生成して返す
    return NT(*dct.values())

# %%
# defaults = dict(prefecture="未設定")
# npj = to_nt(pj, "Project", defaults)
# npj.data_position, npj.project_type, npj.data_category, npj.data_brand, npj.prefecture, npj.sortby

# %%
# defaults = dict(project_exprience="未設定")
# npjd = to_nt(pjd, "ProjectDetails", defaults=defaults)
# npjd.title, npjd.article_text, npjd.type, npjd.profile_text, npjd.project_exprience

# %%
# npj.project_id, npj.execution_id, npj.sortby
# npj.data_position, npj.project_type, npj.data_category, npj.data_brand, npj.prefecture
# npd.title, npd.article_text, npd.type, npd.profile_text, npd.project_exprience
# npj.success_rate, npj.current_funding, npj.current_supporters

# NOTE: using project_id, project_data_id, to get the return_boxes nodes by Cypher query

# %%
# query = """
# match (n:ProjectDataRoot)
# with max(distinct n.execution_id) as eid
# match (pr: ProjectRoot) --> (dr: ProjectDataRoot {execution_id: eid}) --> (pj:Project) --> (pjd:ProjectDetails)
# return pr, dr, pj, pjd
# """

# %%
query = """
match (pr: ProjectRoot) --> (dr: ProjectDataRoot) --> (pj:Project) --> (pjd:ProjectDetails)
return pr, dr, pj, pjd
"""

# %%
results: list[Record] = select_query(query)

# %%
len(results)
# Out:
# 9800

# %%
import pandas as pd


records = []
for idx, rec in enumerate(results):
    record = {}
    [record.update(d) for d in rec.data("pr", "dr", "pj", "pjd").values()]
    records.append(record)

df = pd.DataFrame.from_records(records)

# %%
df.columns
# Out:
# Index(['project_id', 'project_url', 'source_id', 'execution_id', 'data_list',
#        'project_type', 'fetch_id', 'data_category', 'created_at', 'data_brand',
#        'title', 'current_funding', 'project_data_id', 'data_position',
#        'user_id', 'img_url', 'current_supporters', 'sortby', 'data_dimension',
#        'status', 'prefecture', 'profile_url', 'user_name', 'backer_amount',
#        'article_text', 'abstract', 'type', 'article_html', 'profile_text',
#        'project_exprience', 'icon_url', 'success_rate', 'remaining_days',
#        'readmore'],
#       dtype='object')

# %%
df.head(3)
# Out:
#   project_id                                project_url source_id  \
# 0     722442  https://camp-fire.jp/projects/view/722442  Campfire
# 1     722442  https://camp-fire.jp/projects/view/722442  Campfire
# 2     722442  https://camp-fire.jp/projects/view/722442  Campfire
#
#      execution_id                   data_list project_type  \
# 0  20240408010001  projects_most_funded_page4      書籍・雑誌出版
# 1  20240407012401  projects_most_funded_page4      書籍・雑誌出版
# 2  20240406010002  projects_most_funded_page4      書籍・雑誌出版
#
#                         fetch_id        data_category  created_at  \
# 0  FCH01HTWVT1SXYZ4XS277HRV5MGPQ  category_publishing  2024-04-08
# 1  FCH01HTTAP2ZX71J37EHRG6FV1NJQ  category_publishing  2024-04-07
# 2  FCH01HTQQ6NHPMDJH6NHQCW5TNQEP  category_publishing  2024-04-06
#
#              data_brand  ...  \
# 0  faavo_campfire_local  ...
# 1  faavo_campfire_local  ...
# 2  faavo_campfire_local  ...
#
#                                         article_text  \
# 0  Play\nいつも見てくれてる方、いつもありがとうございます♡\n初めましての方は、はじめま...
# 1  Play\nいつも見てくれてる方、いつもありがとうございます♡\n初めましての方は、はじめま...
# 2  Play\nいつも見てくれてる方、いつもありがとうございます♡\n初めましての方は、はじめま...
#
#                                             abstract     type  \
# 0  品川あゆみです。3月15日にゼロワン出版社さんより、初の書籍【ネイリストの常識はお客様の非常...  project
# 1  品川あゆみです。3月15日にゼロワン出版社さんより、初の書籍【ネイリストの常識はお客様の非常...  project
# 2  品川あゆみです。3月15日にゼロワン出版社さんより、初の書籍【ネイリストの常識はお客様の非常...  project
#
#                                         article_html  \
# 0  <h6><img class="fr-fil fr-dib lazyload" style=...
# 1  <h6><img class="fr-fil fr-dib lazyload" style=...
# 2  <h6><img class="fr-fil fr-dib lazyload" style=...
#
#                                         profile_text project_exprience  \
# 0  ayumi_nca\n日本\n初めてのプロジェクトです\n認証していません\nwww.ins...      初めてのプロジェクトです
# 1  ayumi_nca\n日本\n初めてのプロジェクトです\n認証していません\nwww.ins...      初めてのプロジェクトです
# 2  ayumi_nca\n日本\n初めてのプロジェクトです\n認証していません\nwww.ins...      初めてのプロジェクトです
#
#    icon_url success_rate remaining_days readmore
# 0       NaN          NaN            NaN      NaN
# 1       NaN          NaN            NaN      NaN
# 2       NaN          NaN            NaN      NaN
#
# [3 rows x 34 columns]

# %%
df.shape
# Out:
# (9800, 34)

# %%
# set index
keys = ["project_id", "execution_id", "sortby", "project_data_id"]
df.index = [df[k] for k in keys]
df.drop(columns=keys, inplace=True)
df.head()
# Out:
#                                                                                                    project_url  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  https://camp-fire.jp/projects/view/722442
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  https://camp-fire.jp/projects/view/722442
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  https://camp-fire.jp/projects/view/722442
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  https://camp-fire.jp/projects/view/722442
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  https://camp-fire.jp/projects/view/722442
#
#                                                                     source_id  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  Campfire
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  Campfire
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  Campfire
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  Campfire
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  Campfire
#
#                                                                                       data_list  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  projects_most_funded_page4
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  projects_most_funded_page4
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  projects_most_funded_page4
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  projects_most_funded_page4
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  projects_most_funded_page4
#
#                                                                     project_type  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2      書籍・雑誌出版
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E      書籍・雑誌出版
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8      書籍・雑誌出版
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R      書籍・雑誌出版
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX      書籍・雑誌出版
#
#                                                                                           fetch_id  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  FCH01HTWVT1SXYZ4XS277HRV5MGPQ
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  FCH01HTTAP2ZX71J37EHRG6FV1NJQ
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  FCH01HTQQ6NHPMDJH6NHQCW5TNQEP
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  FCH01HTN4WSEGJ0ZQA756MCFHVPZA
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  FCH01HTJJ7JZBT83PHGWMNY9JNSMW
#
#                                                                            data_category  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  category_publishing
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  category_publishing
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  category_publishing
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  category_publishing
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  category_publishing
#
#                                                                      created_at  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  2024-04-08
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  2024-04-07
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  2024-04-06
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  2024-04-05
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  2024-04-04
#
#                                                                                data_brand  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  faavo_campfire_local
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  faavo_campfire_local
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  faavo_campfire_local
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  faavo_campfire_local
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  faavo_campfire_local
#
#                                                                                                      title  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  初出版記念！ネイリストのミライを豊かにする！「ネイルサロン満席予祝まつり」
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  初出版記念！ネイリストのミライを豊かにする！「ネイルサロン満席予祝まつり」
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  初出版記念！ネイリストのミライを豊かにする！「ネイルサロン満席予祝まつり」
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  初出版記念！ネイリストのミライを豊かにする！「ネイルサロン満席予祝まつり」
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  初出版記念！ネイリストのミライを豊かにする！「ネイルサロン満席予祝まつり」
#
#                                                                      current_funding  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2       54969230.0
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E       54969230.0
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8       54969230.0
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R       54969230.0
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX       54969230.0
#
#                                                                      ...  \
# project_id execution_id   sortby      project_data_id                ...
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  ...
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  ...
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  ...
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  ...
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  ...
#
#                                                                                                           article_text  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  Play\nいつも見てくれてる方、いつもありがとうございます♡\n初めましての方は、はじめま...
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  Play\nいつも見てくれてる方、いつもありがとうございます♡\n初めましての方は、はじめま...
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  Play\nいつも見てくれてる方、いつもありがとうございます♡\n初めましての方は、はじめま...
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  Play\nいつも見てくれてる方、いつもありがとうございます♡\n初めましての方は、はじめま...
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  Play\nいつも見てくれてる方、いつもありがとうございます♡\n初めましての方は、はじめま...
#
#                                                                                                               abstract  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  品川あゆみです。3月15日にゼロワン出版社さんより、初の書籍【ネイリストの常識はお客様の非常...
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  品川あゆみです。3月15日にゼロワン出版社さんより、初の書籍【ネイリストの常識はお客様の非常...
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  品川あゆみです。3月15日にゼロワン出版社さんより、初の書籍【ネイリストの常識はお客様の非常...
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  品川あゆみです。3月15日にゼロワン出版社さんより、初の書籍【ネイリストの常識はお客様の非常...
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  品川あゆみです。3月15日にゼロワン出版社さんより、初の書籍【ネイリストの常識はお客様の非常...
#
#                                                                         type  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  project
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  project
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  project
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  project
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  project
#
#                                                                                                           article_html  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  <h6><img class="fr-fil fr-dib lazyload" style=...
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  <h6><img class="fr-fil fr-dib lazyload" style=...
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  <h6><img class="fr-fil fr-dib lazyload" style=...
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  <h6><img class="fr-fil fr-dib lazyload" style=...
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  <h6><img class="fr-fil fr-dib lazyload" style=...
#
#                                                                                                           profile_text  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2  ayumi_nca\n日本\n初めてのプロジェクトです\n認証していません\nwww.ins...
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E  ayumi_nca\n日本\n初めてのプロジェクトです\n認証していません\nwww.ins...
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8  ayumi_nca\n日本\n初めてのプロジェクトです\n認証していません\nwww.ins...
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R  ayumi_nca\n日本\n初めてのプロジェクトです\n認証していません\nwww.ins...
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX  ayumi_nca\n日本\n初めてのプロジェクトです\n認証していません\nwww.ins...
#
#                                                                     project_exprience  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2      初めてのプロジェクトです
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E      初めてのプロジェクトです
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8      初めてのプロジェクトです
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R      初めてのプロジェクトです
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX      初めてのプロジェクトです
#
#                                                                     icon_url  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2      NaN
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E      NaN
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8      NaN
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R      NaN
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX      NaN
#
#                                                                     success_rate  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2          NaN
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E          NaN
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8          NaN
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R          NaN
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX          NaN
#
#                                                                     remaining_days  \
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2            NaN
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E            NaN
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8            NaN
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R            NaN
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX            NaN
#
#                                                                     readmore
# project_id execution_id   sortby      project_data_id
# 722442     20240408010001 most_funded PRJ01HTWVWBCEXPQ7RKDTQG4J4BC2      NaN
#            20240407012401 most_funded PRJ01HTTAR7N9S90Y5C81ZWB7GJ4E      NaN
#            20240406010002 most_funded PRJ01HTQQ8WRY1H3F85X1DFCA0WW8      NaN
#            20240405010001 most_funded PRJ01HTN4YYWM57ERXN2HF6E4P37R      NaN
#            20240404010002 most_funded PRJ01HTJJ9G3VYZ7RV54QXQ8C1KDX      NaN
#
# [5 rows x 30 columns]

# %%
df.to_sql(
    "project_details",
    engine,
    if_exists="replace",
    index=True,
    index_label=keys,
)
# Out:
# 190

# %%
# for idx, grp in df.groupby(by=["project_id", "execution_id"]):
#     # print(grp.keys())
#     print(
#         grp[
#             [
#                 "project_id",
#                 "execution_id",
#                 "status",
#                 "sortby",
#                 "data_position",
#                 "current_funding",
#                 "current_supporters",
#                 "success_rate",
#             ]
#         ]
#     )
#     break
