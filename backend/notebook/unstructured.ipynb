# %% [markdown]
# cf. https://docs.unstructured.io/examplecode/codesamples/apioss/table-extraction-from-pdf#method-1-using-partition-pdf

# %%
from unstructured.partition.auto import partition_pdf

elements = partition_pdf(
    url="https://www.chusho.meti.go.jp/pamflet/hakusyo/2024/PDF/2024gaiyou.pdf",
    infer_table_structure=True,
    strategy="hi_res",
)
elements
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/workspace/backend/.venv/lib/python3.10/site-packages/transformers/utils/import_utils.py:1560, in _LazyModule._get_module(self, module_name)
#    1559 try:
# -> 1560     return importlib.import_module("." + module_name, self.__name__)
#    1561 except Exception as e:
#
# File /usr/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# ...

# %%
print("\n\n".join([str(el) for el in elements]))
