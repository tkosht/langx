# %%
from matplotlib import pyplot
import numpy as np

# %%
x = np.linspace(-np.pi, np.pi)
y = np.sin(x)
  
pyplot.plot(x, y, label="sin")
pyplot.title("波")
pyplot.xlabel("ｘ軸")
pyplot.ylabel("ｙ軸")
pyplot.legend()
pyplot.show()
